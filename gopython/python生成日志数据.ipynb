# %%
from faker import Faker
import json

fake = Faker()
for _ in range(100):
    # 生成时间戳
    timestamp = str(fake.date_time_between_dates(datetime_start=None, datetime_end=None, tzinfo=None))
    # print(timestamp)
    # 生成用户ID

    user_id = "user"+str(fake.random_number(digits=3))

    # 生成页面URL和页面标题
    page_url = fake.url()
    page_title = fake.catch_phrase()

    # 生成动作和元素ID
    action = fake.random_element(elements=('点击', '浏览', '搜索'))
    element_id = fake.uuid4()

    # 生成参考来源
    referrer = fake.url()

    # # 生成设备信息
    device_os = fake.random_element(elements=('Windows', 'MacOS', 'Linux'))
    # device_browser = fake.user_agent_browser()
    # device_resolution = fake.random_element(elements=('1920x1080', '1366x768', '2560x1440'))

    # 生成IP地址和用户代理
    ip_address = fake.ipv4()
    user_agent = fake.user_agent()

    # 生成其他自定义字段
    # custom_field1 = fake.random_element(elements=(1, 2, 3))
    elements=["要闻.经济_科技","观点.三评","观点.人民财评","观点.人民来论","观点.人民访谈","观点.人民体谈","要闻.社会_法治","要闻.文旅_体育","健康_生活","要闻.国际","要闻.军事","要闻.港澳" "要闻.台湾","要闻.教育","要闻.科普","地方.京","地方.津","地方.冀","地方.晋","地方.蒙", "地方.辽","地方.吉","地方.黑","地方.沪","地方.苏","地方.浙","地方.皖","地方.闽","地方.赣","地方.鲁" "地方.豫" "地方.鄂" "地方.湘" "地方.粤","地方.桂","地方.琼","地方.渝","地方.川","地方.黔","地方.滇","地方.藏","地方.陕","地方.甘","地方.青","地方.宁","地方.新","地方.鹏","地方.雄安"]
    # 要闻.经济_科技  要闻.社会_法治  要闻.文旅_体育 健康_生活 要闻.国际 要闻.军事 要闻.港澳 要闻.台湾 要闻.教育 要闻.科普
    # 观点.人民网评 观点.三评 观点.人民财评 观点.人民来论 观点.人民访谈 观点.人民体谈
    # 地方.京 地方.津 地方.冀 地方.晋 地方.蒙 地方.辽 地方.吉 地方.黑 地方.沪 地方.苏 地方.浙 地方.皖 地方.闽 地方.赣 地方.鲁 地方.豫 地方.鄂 地方.湘 地方.粤 地方.桂 地方.琼 地方.渝 地方.川 地方.黔 地方.滇 地方.藏 地方.陕 地方.甘 地方.青 地方.宁 地方.新 地方.鹏 地方.雄安
    # page_title=fake.random_element(elements=("要闻.经济_科技","观点.三评","观点.人民财评","观点.人民来论","观点.人民访谈","观点.人民体谈"))
    load_type=fake.random_element(elements)
    custom_field2 = fake.random_number(digits=2)
    http_status=fake.random_element(elements=(200,500,404,503,502,403))

    # 构建Web点击日志数据
    web_log = {
        'timestamp': timestamp,
        'ip_address': ip_address,
        'user_id': user_id,
        'load_type': load_type,
        'page_url': page_url,
        'referrer': referrer,
        'http_status':http_status,
        'page_title': page_title,
        'device_os':device_os,
        'user_agent': user_agent,
    #     'action': action,÷÷¿˘≤≤≥≤˘¯ÆÚÆÆÆÚæ……æ“‘“‘‘”’–≠≠ºª•¶§∞¢£®††¥¶ˆ¨¥†®®´∂
    #     'element_id': element_id,
    #     'custom_field2': custom_field2
    }


#     print(web_log)


    with open('web_log.json', 'a') as f:
    #     json.dumps(web_log,indent=None)
        f.write(json.dumps(web_log,indent=None, ensure_ascii=False))
        f.write("\n")  # 手动添加换行符


print('Web点击日志数据已保存为JSON文件')
# Out:
# Web点击日志数据已保存为JSON文件

# %%
import json

# 生成Web点击日志数据

# web_log = {
#     '时间戳': '2023-04-17 15:30:45',
#     '用户ID': '123456789',
#     '页面URL': 'https://example.com/products/12345',
#     '页面标题': '示例产品页面',
#     '动作': '点击',
#     '元素ID': 'product-image-12345',
#     '参考来源': 'https://example.com/category/electronics',
#     '设备信息': {
#         '操作系统': 'Windows 10',
#         '浏览器': 'Chrome 89.0.4389.82',
#         '屏幕分辨率': '1920x1080'
#     },
#     'IP地址': '192.168.1.100',
#     '用户代理': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36',
#     '其他自定义字段1': '男',
#     '其他自定义字段2': 25
# }

# 将Web点击日志数据保存为JSON文件
# Out:
# Web点击日志数据已保存为JSON文件

# %%
print('当前年月日时分秒：', fake.date_time_between_dates(datetime_start=None, datetime_end=None, tzinfo=None))
# Out:
# 当前年月日时分秒： 2023-04-17 16:03:23

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions
# 创建SparkSession对象
spark = SparkSession.builder.appName("WebLogs").getOrCreate()

# 读取JSON格式的Web日志文件
# readJSONDF = spark.read.json('web_log.json')
# readJSONDF.show(truncate=False)
# web_logs = spark.read.option('multiline', True).json('web_log.json')
web_logs = spark.read.json('web_log.json')
# Out:
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/28 19:38:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
web_logs.show()
# Out:
# +---------+-----------+---------------+--------------+--------------------+--------------------+--------------------+-------------------+--------------------+-------+
# |device_os|http_status|     ip_address|     load_type|          page_title|            page_url|            referrer|          timestamp|          user_agent|user_id|
# +---------+-----------+---------------+--------------+--------------------+--------------------+--------------------+-------------------+--------------------+-------+
# |    Linux|        502|  104.124.50.98|要闻.经济_科技|Multi-layered eco...|http://www.aguila...|http://www.brown-...|2023-04-28 19:37:44|Mozilla/5.0 (comp...|user790|
# |    MacOS|        500|   48.76.46.145| 观点.人民访谈|Compatible real-t...|https://lambert.com/|http://www.johnso...|2023-04-28 19:37:44|Mozilla/5.0 (Wind...|user258|
# |    Linux|        502|  68.131.248.19| 观点.人民财评|Self-enabling hum...|http://clark-mcbr...|https://evans-gal...|2023-04-28 19:37:44|Mozilla/5.0 (X11;...|user969|
# |    MacOS|        200|133.195.189.221|     观点.三评|Open-source conte...|https://www.sharp...|https://martinez....|2023-04-28 19:37:44|Mozilla/5.0 (Linu...|user211|
# |    Linux|        500| 207.66.172.130| 观点.人民体谈|Team-oriented rec...| http://www.lee.com/|http://www.burns-...|2023-04-28 19:37:44|Mozilla/5.0 (iPod...| user32|
# |    MacOS|        502|  205.94.40.108| 观点.人民体谈|Persistent multi-...|http://www.anders...|http://www.yoder....|2023-04-28 19:37:44|Mozilla/5.0 (Andr...|user317|
# |    Linux|        500|  104.27.53.171|     观点.三评|Inverse bottom-li...|http://www.white....|   http://owens.com/|2023-04-28 19:37:44|Mozilla/5.0 (Maci...|user860|
# |    MacOS|        500|  207.17.41.186| 观点.人民财评|Re-engineered max...|https://gomez-sim...|http://www.whitne...|2023-04-28 19:37:44|Mozilla/5.0 (comp...|user222|
# |    Linux|        503|  76.87.174.156| 观点.人民来论|Reactive even-kee...|http://www.gordon...|https://www.rodri...|2023-04-28 19:37:44|Mozilla/5.0 (iPho...|user679|
# |    MacOS|        403| 187.146.72.243|要闻.经济_科技|Assimilated bandw...|https://www.arnol...|https://www.mayer...|2023-04-28 19:37:44|Mozilla/5.0 (Andr...|user464|
# |    Linux|        404| 136.62.227.199| 观点.人民财评|Exclusive tangibl...| https://mclean.org/|http://www.long.com/|2023-04-28 19:37:44|Opera/9.69.(Windo...|user918|
# |    Linux|        502|  72.134.84.192|     观点.三评|Total stable init...|https://www.barne...|https://www.varga...|2023-04-28 19:37:44|Mozilla/5.0 (comp...|user168|
# |    Linux|        503|   90.111.55.40|要闻.经济_科技|Future-proofed hu...|https://www.hunt....|https://www.burge...|2023-04-28 19:37:44|Opera/8.41.(X11; ...|user564|
# |    MacOS|        500|196.203.112.112|     观点.三评|Grass-roots 24hou...| https://tucker.biz/|   http://moody.com/|2023-04-28 19:37:44|Opera/9.51.(X11; ...|user402|
# |  Windows|        502|    88.46.29.82| 观点.人民财评|Managed global fo...|https://stewart-b...|  https://poole.biz/|2023-04-28 19:37:44|Mozilla/5.0 (Linu...|user704|
# |    Linux|        502| 204.214.135.56| 观点.人民访谈|Mandatory user-fa...| https://howard.com/| https://acosta.com/|2023-04-28 19:37:44|Mozilla/5.0 (Maci...|user651|
# |    MacOS|        500|   89.113.3.145|     观点.三评|Object-based high...|http://rodriguez....|http://www.ramire...|2023-04-28 19:37:44|Mozilla/5.0 (comp...|  user4|
# |  Windows|        404| 78.104.240.225| 观点.人民财评|Reactive bandwidt...|https://www.singh...|https://www.nicho...|2023-04-28 19:37:44|Mozilla/5.0 (comp...| user47|
# |    Linux|        403|118.212.104.104|     观点.三评|Decentralized con...|https://www.schne...|  http://harris.com/|2023-04-28 19:37:44|Mozilla/5.0 (comp...|user151|
# |  Windows|        404| 81.193.209.249| 观点.人民来论|Profit-focused fu...|http://www.martin...|http://thompson.biz/|2023-04-28 19:37:44|Mozilla/5.0 (iPho...| user15|
# +---------+-----------+---------------+--------------+--------------------+--------------------+--------------------+-------------------+--------------------+-------+
# only showing top 20 rows

# %%
# 选择需要的字段
selected_logs = web_logs.select("user_id","timestamp", "ip_address", "load_type", "page_title")
selected_logs.show()
# 过滤出状态码为200的数据
# filtered_logs = selected_logs.filter(selected_logs.status == "200")

# # 按IP地址分组并计算每个IP地址的请求数量
# ip_counts = selected_logs.groupBy("page_title").count()
# Out:
# +-------+-------------------+---------------+--------------+--------------------+
# |user_id|          timestamp|     ip_address|     load_type|          page_title|
# +-------+-------------------+---------------+--------------+--------------------+
# |user790|2023-04-28 19:37:44|  104.124.50.98|要闻.经济_科技|Multi-layered eco...|
# |user258|2023-04-28 19:37:44|   48.76.46.145| 观点.人民访谈|Compatible real-t...|
# |user969|2023-04-28 19:37:44|  68.131.248.19| 观点.人民财评|Self-enabling hum...|
# |user211|2023-04-28 19:37:44|133.195.189.221|     观点.三评|Open-source conte...|
# | user32|2023-04-28 19:37:44| 207.66.172.130| 观点.人民体谈|Team-oriented rec...|
# |user317|2023-04-28 19:37:44|  205.94.40.108| 观点.人民体谈|Persistent multi-...|
# |user860|2023-04-28 19:37:44|  104.27.53.171|     观点.三评|Inverse bottom-li...|
# |user222|2023-04-28 19:37:44|  207.17.41.186| 观点.人民财评|Re-engineered max...|
# |user679|2023-04-28 19:37:44|  76.87.174.156| 观点.人民来论|Reactive even-kee...|
# |user464|2023-04-28 19:37:44| 187.146.72.243|要闻.经济_科技|Assimilated bandw...|
# |user918|2023-04-28 19:37:44| 136.62.227.199| 观点.人民财评|Exclusive tangibl...|
# |user168|2023-04-28 19:37:44|  72.134.84.192|     观点.三评|Total stable init...|
# |user564|2023-04-28 19:37:44|   90.111.55.40|要闻.经济_科技|Future-proofed hu...|
# |user402|2023-04-28 19:37:44|196.203.112.112|     观点.三评|Grass-roots 24hou...|
# |user704|2023-04-28 19:37:44|    88.46.29.82| 观点.人民财评|Managed global fo...|
# |user651|2023-04-28 19:37:44| 204.214.135.56| 观点.人民访谈|Mandatory user-fa...|
# |  user4|2023-04-28 19:37:44|   89.113.3.145|     观点.三评|Object-based high...|
# | user47|2023-04-28 19:37:44| 78.104.240.225| 观点.人民财评|Reactive bandwidt...|
# |user151|2023-04-28 19:37:44|118.212.104.104|     观点.三评|Decentralized con...|
# | user15|2023-04-28 19:37:44| 81.193.209.249| 观点.人民来论|Profit-focused fu...|
# +-------+-------------------+---------------+--------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql import functions
split_col = functions.split(selected_logs['timestamp'], ' ')
df = selected_logs.withColumn('timestamp', split_col.getItem(0))
# df = selected_logs.withColumn('NAME2', split_col.getItem(1)).show()
# 按IP地址分组并计算每个IP地址的请求数量
df.show()
ip_counts = df.groupBy("load_type").count()
# Out:
# +-------+----------+---------------+--------------+--------------------+
# |user_id| timestamp|     ip_address|     load_type|          page_title|
# +-------+----------+---------------+--------------+--------------------+
# |user790|2023-04-28|  104.124.50.98|要闻.经济_科技|Multi-layered eco...|
# |user258|2023-04-28|   48.76.46.145| 观点.人民访谈|Compatible real-t...|
# |user969|2023-04-28|  68.131.248.19| 观点.人民财评|Self-enabling hum...|
# |user211|2023-04-28|133.195.189.221|     观点.三评|Open-source conte...|
# | user32|2023-04-28| 207.66.172.130| 观点.人民体谈|Team-oriented rec...|
# |user317|2023-04-28|  205.94.40.108| 观点.人民体谈|Persistent multi-...|
# |user860|2023-04-28|  104.27.53.171|     观点.三评|Inverse bottom-li...|
# |user222|2023-04-28|  207.17.41.186| 观点.人民财评|Re-engineered max...|
# |user679|2023-04-28|  76.87.174.156| 观点.人民来论|Reactive even-kee...|
# |user464|2023-04-28| 187.146.72.243|要闻.经济_科技|Assimilated bandw...|
# |user918|2023-04-28| 136.62.227.199| 观点.人民财评|Exclusive tangibl...|
# |user168|2023-04-28|  72.134.84.192|     观点.三评|Total stable init...|
# |user564|2023-04-28|   90.111.55.40|要闻.经济_科技|Future-proofed hu...|
# |user402|2023-04-28|196.203.112.112|     观点.三评|Grass-roots 24hou...|
# |user704|2023-04-28|    88.46.29.82| 观点.人民财评|Managed global fo...|
# |user651|2023-04-28| 204.214.135.56| 观点.人民访谈|Mandatory user-fa...|
# |  user4|2023-04-28|   89.113.3.145|     观点.三评|Object-based high...|
# | user47|2023-04-28| 78.104.240.225| 观点.人民财评|Reactive bandwidt...|
# |user151|2023-04-28|118.212.104.104|     观点.三评|Decentralized con...|
# | user15|2023-04-28| 81.193.209.249| 观点.人民来论|Profit-focused fu...|
# +-------+----------+---------------+--------------+--------------------+
# only showing top 20 rows

# %%
ip_counts.show()
# Out:
# +--------------+-----+
# |     load_type|count|
# +--------------+-----+
# |要闻.经济_科技|   14|
# |     观点.三评|   21|
# | 观点.人民访谈|   17|
# | 观点.人民来论|   11|
# | 观点.人民财评|   23|
# | 观点.人民体谈|   14|
# +--------------+-----+

# %%
import random
import string


def get_ip():
           '203.86.64.0', '203.88.32.0', '203.88.192.0', '203.89.0.0', '203.90.0.0', '203.90.128.0', '203.90.192.0',
           '203.91.32.0', '203.91.96.0', '203.91.120.0', '203.92.0.0', '203.92.160.0', '203.93.0.0', '203.94.0.0', '203.95.0.0',
           '203.95.96.0', '203.99.16.0', '203.99.80.0', '203.100.32.0', '203.100.80.0', '203.100.96.0', '203.100.192.0',
           '203.110.160.0', '203.118.192.0', '203.119.24.0', '203.119.32.0', '203.128.32.0', '203.128.96.0', '203.130.32.0',
           '203.132.32.0', '203.134.240.0', '203.135.96.0', '203.135.160.0', '203.142.219.0', '203.148.0.0', '203.152.64.0',
           '203.156.192.0', '203.158.16.0', '203.161.192.0', '203.166.160.0', '203.171.224.0', '203.174.7.0', '203.174.96.0',
           '203.175.128.0', '203.175.192.0', '203.176.168.0', '203.184.80.0', '203.187.160.0', '203.190.96.0', '203.191.16.0',
           '203.191.64.0', '203.191.144.0', '203.192.0.0', '203.196.0.0', '203.207.64.0', '203.207.128.0', '203.208.0.0',
           '203.208.16.0', '203.208.32.0', '203.209.224.0', '203.212.0.0', '203.212.80.0', '203.222.192.0', '203.223.0.0',
           '210.2.0.0', '210.5.0.0', '210.5.144.0', '210.12.0.0', '210.14.64.0', '210.14.112.0', '210.14.128.0', '210.15.0.0',
           '210.15.128.0', '210.16.128.0', '210.21.0.0', '210.22.0.0', '210.23.32.0', '210.25.0.0', '210.26.0.0', '210.28.0.0',
           '210.32.0.0', '210.51.0.0', '210.52.0.0', '210.56.192.0', '210.72.0.0', '210.76.0.0', '210.78.0.0', '210.79.64.0',
           '210.79.224.0', '210.82.0.0', '210.87.128.0', '210.185.192.0', '210.192.96.0', '211.64.0.0', '211.80.0.0',
           '211.96.0.0', '211.136.0.0', '211.144.0.0', '211.160.0.0', '218.0.0.0', '218.56.0.0', '218.64.0.p0', '218.96.0.0',
           '218.104.0.0', '218.108.0.0', '218.185.192.0', '218.192.0.0', '218.240.0.0', '218.249.0.0', '219.72.0.0',
           '219.82.0.0', '219.128.0.0', '219.216.0.0', '219.224.0.0', '219.242.0.0', '219.244.0.0', '220.101.192.0',
           '220.112.0.0', '220.152.128.0', '220.154.0.0', '220.160.0.0', '220.192.0.0', '220.231.0.0', '220.231.128.0',
           '220.232.64.0', '220.234.0.0', '220.242.0.0', '220.248.0.0', '220.252.0.0', '221.0.0.0', '221.8.0.0', '221.12.0.0',
           '221.12.128.0', '221.13.0.0', '221.14.0.0', '221.122.0.0', '221.129.0.0', '221.130.0.0', '221.133.224.0',
           '221.136.0.0', '221.172.0.0', '221.176.0.0', '221.192.0.0', '221.196.0.0', '221.198.0.0', '221.199.0.0',
           '221.199.128.0', '221.199.192.0', '221.199.224.0', '221.200.0.0', '221.208.0.0', '221.224.0.0', '222.16.0.0',
           '222.32.0.0', '222.64.0.0', '222.125.0.0', '222.126.128.0', '222.128.0.0', '222.160.0.0', '222.168.0.0',
           '222.176.0.0', '222.192.0.0', '222.240.0.0', '222.248.0.0']
    rnd = random.randint(0, len(ips) - 1)
    ip = ips[rnd]
    _ip = ip.split('.')
    for i, v in enumerate(_ip):
        if int(v) == 0:
            _ip[i] = str(random.randint(0, 255))
    ip = '.'.join(_ip)
    return ip
print(get_ip())
# Out:
# 116.95.39.56
